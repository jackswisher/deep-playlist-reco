# %%
import os
import sys
import glob
import time
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
sns.set(style="ticks")

# %%
df = pd.read_csv("20k_srs_songs.csv.csv")

# %%
plt.hist(df['danceability'])
plt.show()

# %%
sns.pairplot(df)
