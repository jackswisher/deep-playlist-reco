# %%
import os
import sys
import glob
import time
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import random
import sklearn
from sklearn.metrics.pairwise import cosine_similarity

# %%
playlists_df = pd.read_csv("playlist_data.csv")

# %%
total_songs = pd.read_csv("total_songs_clean.csv")

# %%
most_popular_songs = pd.read_csv("top70ksongs.csv")

# %%
total_songs.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.369  0.2230    9   -15.993     1       0.0564      0.957000
# 1         0.664  0.6050    4    -5.477     0       0.2580      0.242000
# 2         0.740  0.7120    9    -7.260     0       0.0814      0.071800
# 3         0.623  0.8630    1    -8.161     0       0.0776      0.000811
# 4         0.413  0.0302   10   -26.692     1       0.0350      0.957000
#
#    instrumentalness  liveness  valence  ...            type  \
# 0          0.860000     0.124    0.212  ...  audio_features
# 1          0.000000     0.161    0.397  ...  audio_features
# 2          0.000000     0.330    0.742  ...  audio_features
# 3          0.000002     0.128    0.734  ...  audio_features
# 4          0.443000     0.113    0.254  ...  audio_features
#
#                        id                                   uri  \
# 0  3R8bbBLfCrl3wXELLDuZiA  spotify:track:3R8bbBLfCrl3wXELLDuZiA
# 1  5Zk7ELDEXqcHZk2euHPVb9  spotify:track:5Zk7ELDEXqcHZk2euHPVb9
# 2  5tg8mN8KqRfwIvkXF0tRr4  spotify:track:5tg8mN8KqRfwIvkXF0tRr4
# 3  10qeFHxbayfrkH2kX9kTnv  spotify:track:10qeFHxbayfrkH2kX9kTnv
# 4  18LVcYNiF05oDfEQ7HEhNR  spotify:track:18LVcYNiF05oDfEQ7HEhNR
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3R8bbBLfCrl3...
# 1  https://api.spotify.com/v1/tracks/5Zk7ELDEXqcH...
# 2  https://api.spotify.com/v1/tracks/5tg8mN8KqRfw...
# 3  https://api.spotify.com/v1/tracks/10qeFHxbayfr...
# 4  https://api.spotify.com/v1/tracks/18LVcYNiF05o...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3R8b...      196733
# 1  https://api.spotify.com/v1/audio-analysis/5Zk7...      192320
# 2  https://api.spotify.com/v1/audio-analysis/5tg8...      276093
# 3  https://api.spotify.com/v1/audio-analysis/10qe...      136067
# 4  https://api.spotify.com/v1/audio-analysis/18LV...      233627
#
#    time_signature           artist_name  \
# 0               4      Kagan Publishing
# 1               4      Cherine Anderson
# 2               4         Kirk Franklin
# 3               4                  Limp
# 4               4  Ludwig van Beethoven
#
#                                           track_name  \
# 0                                  The Road to Lucia
# 1           Coming Over Tonight (feat. Chuck Fender)
# 2                                     Keep Your Head
# 3                                          Bug Dance
# 4  Beethoven : Symphony No.8 in F major Op.93 : I...
#
#                           album_name
# 0  Brain Boosters: Inspired Thinking
# 1              The Introduction - EP
# 2                               Hero
# 3                   Pop & Disorderly
# 4   Beethoven : Symphonies Nos 1 - 9
#
# [5 rows x 21 columns]

# %%
playlists_df.head()
# Out:
#    pid  pos              artist_name                             track_uri  \
# 0    0    0         Sleeping At Last  spotify:track:2d7LPtieXdIYzf7yHPooWd
# 1    0    1         Rachael Yamagata  spotify:track:0y4TKcc7p2H6P0GJlt01EI
# 2    0    2  The Cinematic Orchestra  spotify:track:6q4c1vPRZREh7nw3wG7Ixz
# 3    0    3  The Cinematic Orchestra  spotify:track:54KFQB6N4pn926IUUYZGzK
# 4    0    4             Leon Bridges  spotify:track:0NeJjNlprGfZpeX2LQuN6c
#
#                               artist_uri       track_name  \
# 0  spotify:artist:0MeLMJJcouYXCymQSHPn8g     Chasing Cars
# 1  spotify:artist:7w0qj2HiAPIeUcoPogvOZ6        Elephants
# 2  spotify:artist:32ogthv0BdaSMPml02X9YB        That Home
# 3  spotify:artist:32ogthv0BdaSMPml02X9YB  To Build A Home
# 4  spotify:artist:3qnGvpP8Yth1AqSBMqON5x            River
#
#                               album_uri  duration_ms  \
# 0  spotify:album:0UIIvTTWNB3gRQWFoxoEDh       242564
# 1  spotify:album:6KzK9fDNmj7GHFbcE4gVJD       253701
# 2  spotify:album:5cPHT4yMCfETLRYAoBFcOZ       103920
# 3  spotify:album:5cPHT4yMCfETLRYAoBFcOZ       371320
# 4  spotify:album:4svLfrPPk2npPVuI4kXPYg       238560
#
#                              album_name  fid
# 0                        Covers, Vol. 2  284
# 1  Elephants...Teeth Sinking Into Heart  284
# 2                              Ma Fleur  284
# 3                              Ma Fleur  284
# 4                           Coming Home  284

# %% [markdown]
# ## Create a baseline model class

# %% [markdown]
# For our baseline model, we decided to recommend songs from a set of candidate songs according to which of these candidates have the highest average cosine similarity to the set of seed songs. To elaborate, the function is applied pairwise between each candidate and each seed song and then the output is averaged across the seed songs giving an average similarity for each candidate. In other words, playlists are generated using an unsupervised algorithm that attempts to maximize a score function and can generate playlists of any length up to the number of provided candidate songs. For our purposes, we used a collection of around 220,000 candidate songs, which is noteably 1/10th of all unique songs used to create playlists in our dataset.
#
# This approach is motivated by the assumption that different playlists have different distributions of features, perhaps according to genre for example, and that songs that are tonally similar will be a good recommendation for that playlist.
#
# This leaves us with a couple of ways to improve performance. First, our baseline model used `"danceability", "energy", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "mode"` to measure difference, however this selection of features could certainly be tuned for model performance. Second, this similarity function could be changed completely, perhaps using a supervised ML algorithm such as a neural network where the algorithm predicts similarity between songs trained on top spotify playlists, while preserving the structure of our baseline model.

# %%
class Baseline:
    def __init__(self, X_train, X_test, songs_df, candidate_song_ids = None, 
                 candidate_percentage = 0.3, similarity = "cosine"):
        self.X_train = X_train
        self.X_test = X_test
        self.songs_df = songs_df
        sids = set(songs_df["id"])
        self.sids = sids
        if candidate_song_ids:
            # make sure the ids are in the songs_df
            assert(sum([0 if i in sids else 1 for i in candidate_songs_ids]) == 0)
            self.candidate_songs = songs_df.loc[songs_df["id"].isin(candidate_song_ids)]
        else:
            self.setCandidateSongs(candidate_percentage)
        
        if similarity == "cosine":
            self.sim_func = cosine_similarity
        else:
            raise NotImplementedError("This similarity function is not currently supported.")
            
        # used song set?
        self.used_song_ids = set()
        
        
    def setCandidateSongs(self, percentage):
        ids = random.sample(list(self.sids), int(percentage * len(self.sids)))
        self.candidate_songs = self.songs_df.loc[self.songs_df["id"].isin(ids)]
        
    
    def predict(self, seed_songs_df, num_songs, feats_to_use):
        songs_to_consider = self.candidate_songs.loc[-self.candidate_songs["id"].isin(list(seed_songs_df["id"]))]
        similarities = self.sim_func(seed_songs_df[feats_to_use].values, 
                                     songs_to_consider[feats_to_use].values)
        avg_sim = np.mean(similarities, axis = 0)
        desc_order = np.argsort(-avg_sim)
        songs_desc = songs_to_consider.iloc[desc_order]
        return songs_desc[0:num_songs]

# %%
test = Baseline("a", "b", total_songs.iloc[0:1000], candidate_percentage=1)

# %%
available_features = ["danceability", "energy", "loudness", 
                      "speechiness", "acousticness", 
                      "instrumentalness", "liveness", "valence", "mode"]

# %%
predicted = test.predict(total_songs.iloc[0:99], 1000, available_features)

# %% [markdown]
# ## Evaluating our model on our complete playlists

# %% [markdown]
# To evaluate our baseline model, we randomly selected 50 playlists and retrieved all of their songs to ensure that we had musical features on all of the playlist entries. Next, we split these playlists into a set of "seed" songs and evaluation songs of sizes 0.75 and 0.25, respectively. Finally, we used our baseline model to predict 500 songs that our model deemed as best matches. We then compared these predictions to the left-out test set and recorded the percentage of the playlist songs that were predicted correctly. Using this metric, our model predicted $2.5\%$ of the test set correctly on average.
#
# Furthermore, we record the positions of the correctly predicted test set where 1 is considered a better match than 500. Looking at this data, we see that there are a few playlists where the model gets many of the test set correct and other playlists where the baseline model predicted none of the original songs. This might suggest that some playlists are tonally similar while others are less so; this may motivate another angle of approach that attempts to use related artists to those found in the seed songs to avoid only suggesting tonally similar songs.

# %%
complete_playlists = pd.read_csv("complete_playlists_50.csv")

# %%
unique_playlists = complete_playlists.groupby(by=["fid", "pid"]).pos.first().reset_index().drop("pos", axis=1)

# %%
percent = 3/4
test_size = 0
num_correct = 0
position_list = {}
random.seed(109)
for i in range(len(unique_playlists)): #len(unique_playlists)
    fid = unique_playlists.loc[i, "fid"]
    pid = unique_playlists.loc[i, "pid"]
    playlist = complete_playlists.loc[(complete_playlists["fid"] == fid) & 
                                      (complete_playlists["pid"] == pid)].reset_index(drop=True)
    
    seed_ids = random.sample(list(range(playlist.shape[0])), int(playlist.shape[0] * percent))
    seed_split = playlist.index.get_level_values(0).isin(seed_ids)
    seed = playlist.loc[seed_split]
    test = playlist.loc[~seed_split]
    test_song_ids = set(test["id"])
    test_size += test.shape[0]
    evaluate = Baseline("not", "implemented", total_songs, candidate_percentage=1)
    predictions = evaluate.predict(seed, 500, available_features).reset_index()
    num_correct += predictions.loc[predictions["id"].isin(test_song_ids)].shape[0]
    position_list[(fid, pid)] = (list(predictions.loc[predictions["id"].isin(test_song_ids)].index.get_level_values(0)))

# %%
position_list
# Out:
# {(16, 705): [],
#  (29, 736): [],
#  (52, 746): [],
#  (112, 480): [167, 318, 358, 451],
#  (113, 190): [],
#  (124, 951): [],
#  (149, 299): [204],
#  (164, 985): [96],
#  (167, 82): [],
#  (172, 599): [],
#  (176, 116): [],
#  (226, 831): [],
#  (246, 757): [361],
#  (320, 851): [134, 142],
#  (334, 229): [],
#  (341, 453): [266, 486],
#  (342, 824): [],
#  (346, 794): [],
#  (354, 557): [],
#  (356, 420): [],
#  (361, 820): [],
#  (386, 719): [],
#  (392, 266): [],
#  (420, 39): [],
#  (429, 375): [],
#  (436, 869): [],
#  (447, 778): [107, 157, 348, 451, 479, 485],
#  (451, 640): [387],
#  (508, 314): [],
#  (526, 566): [],
#  (560, 929): [],
#  (680, 108): [196, 215],
#  (718, 872): [],
#  (735, 66): [],
#  (759, 574): [],
#  (770, 309): [],
#  (812, 749): [],
#  (819, 419): [],
#  (823, 120): [],
#  (828, 766): [336],
#  (858, 844): [350, 386],
#  (859, 769): [],
#  (863, 519): [],
#  (865, 866): [],
#  (892, 979): [],
#  (897, 643): [],
#  (921, 300): [],
#  (964, 992): [],
#  (965, 905): [],
#  (998, 452): []}

# %%
num_correct / test_size
# Out:
# 0.02505446623093682

# %%
complete_playlists.loc[(complete_playlists["fid"] == 447) & 
                                      (complete_playlists["pid"] == 778)]
# Out:
#       pid  pos          artist_name                             track_uri  \
# 2773  778    0           Calibre 50  spotify:track:49ItgqFP5shdUdK9ggonW0
# 2774  778    1           Calibre 50  spotify:track:3imJHohXBxDGovFRQ75dUt
# 2775  778    2  Banda Los Recoditos  spotify:track:0N4d44DDwQxBxlzS79uN88
# 2776  778    3  Banda Los Recoditos  spotify:track:0LCMFLgIISg4Mab1YL5shU
# 2777  778    4      Banda El Recodo  spotify:track:2KpFQ5ETwtC3FUGeXhw55I
# ...   ...  ...                  ...                                   ...
# 2889  778  115  Banda Los Recoditos  spotify:track:2uMQxOPITUivAkAYrR02Br
# 2890  778  116  Banda Los Recoditos  spotify:track:2K0HJOlFioRNNnkCABaYZy
# 2891  778  117            Frankie J  spotify:track:7iQY2alDQ2MVya5up2hDgq
# 2892  778  118  Banda Los Recoditos  spotify:track:1PPswVdqYYvfBIk5MdB4Lo
# 2893  778  119        Gerardo Ortiz  spotify:track:6c5ghmeB5B3eUwO9Gr4Dgx
#
#                                  artist_uri  \
# 2773  spotify:artist:4jogXSSvlyMkODGSZ2wc2P
# 2774  spotify:artist:4jogXSSvlyMkODGSZ2wc2P
# 2775  spotify:artist:4bPiOPI4V99cepEftvBYak
# 2776  spotify:artist:4bPiOPI4V99cepEftvBYak
# 2777  spotify:artist:6AcOTCYBMvjKYy4zms0kaC
# ...                                     ...
# 2889  spotify:artist:4bPiOPI4V99cepEftvBYak
# 2890  spotify:artist:4bPiOPI4V99cepEftvBYak
# 2891  spotify:artist:3sMYEBy0CZFxedcnm9i9hf
# 2892  spotify:artist:4bPiOPI4V99cepEftvBYak
# 2893  spotify:artist:4J13m9IZh03PEhoxAxRhXO
#
#                                        track_name  \
# 2773                    Aunque Ahora Estés Con Él
# 2774                                      Contigo
# 2775                               Me Sobrabas Tú
# 2776                                     Pistearé
# 2777                         La Miel De Su Saliva
# ...                                           ...
# 2889                            Cuando Fuiste Mía
# 2890                                Fuego Cruzado
# 2891  Obsesion (No Es Amor) - Featuring Baby Bash
# 2892                             Me Está Gustando
# 2893                          Para Qué Lastimarme
#
#                                  album_uri  duration_ms  \
# 2773  spotify:album:7qS6xf08vzZcHRgwnQsGRP       214293
# 2774  spotify:album:67FKNGl2Yujo7UFeDNajHt       210440
# 2775  spotify:album:1qSHp3vmj7Wm1LmRm8JbNQ       181986
# 2776  spotify:album:3LLGf8yNKPKud3ErCdOkAu       144613
# 2777  spotify:album:4Tl5QOkNgX6INDWg6mMfZB       180119
# ...                                    ...          ...
# 2889  spotify:album:37KAZDlCcCpLZuVltkaQfQ       216013
# 2890  spotify:album:37KAZDlCcCpLZuVltkaQfQ       158253
# 2891  spotify:album:27ybknbObpx7ZWiaWvSF36       225426
# 2892  spotify:album:3LLGf8yNKPKud3ErCdOkAu       180146
# 2893  spotify:album:7FigJmHjjpHHmbTcqtGbRf       175026
#
#                                 album_name  fid  ...  acousticness  \
# 2773             Aunque Ahora Estés Con Él  447  ...        0.5450
# 2774                               Contigo  447  ...        0.7130
# 2775                             Sueño XXX  447  ...        0.6980
# 2776                      Me Está Gustando  447  ...        0.4810
# 2777                   Mi Vicio Más Grande  447  ...        0.4720
# ...                                    ...  ...  ...           ...
# 2889                 Los Gustos Que Me Doy  447  ...        0.5020
# 2890                 Los Gustos Que Me Doy  447  ...        0.3830
# 2891  Playlist: The Very Best Of Frankie J  447  ...        0.0851
# 2892                      Me Está Gustando  447  ...        0.4990
# 2893                Comeré Callado, Vol. 1  447  ...        0.5830
#
#       instrumentalness  liveness  valence    tempo            type  \
# 2773          0.000000    0.3750    0.748  172.507  audio_features
# 2774          0.000236    0.3060    0.596  136.947  audio_features
# 2775          0.000000    0.2600    0.961  154.926  audio_features
# 2776          0.000000    0.3320    0.960  120.021  audio_features
# 2777          0.000002    0.0793    0.963  178.018  audio_features
# ...                ...       ...      ...      ...             ...
# 2889          0.000000    0.0695    0.971  142.039  audio_features
# 2890          0.000000    0.1140    0.886  210.038  audio_features
# 2891          0.000000    0.3250    0.559   75.038  audio_features
# 2892          0.000000    0.1940    0.966  144.903  audio_features
# 2893          0.000000    0.2210    0.767  139.859  audio_features
#
#                           id  \
# 2773  49ItgqFP5shdUdK9ggonW0
# 2774  3imJHohXBxDGovFRQ75dUt
# 2775  0N4d44DDwQxBxlzS79uN88
# 2776  0LCMFLgIISg4Mab1YL5shU
# 2777  2KpFQ5ETwtC3FUGeXhw55I
# ...                      ...
# 2889  2uMQxOPITUivAkAYrR02Br
# 2890  2K0HJOlFioRNNnkCABaYZy
# 2891  7iQY2alDQ2MVya5up2hDgq
# 2892  1PPswVdqYYvfBIk5MdB4Lo
# 2893  6c5ghmeB5B3eUwO9Gr4Dgx
#
#                                              track_href  \
# 2773  https://api.spotify.com/v1/tracks/49ItgqFP5shd...
# 2774  https://api.spotify.com/v1/tracks/3imJHohXBxDG...
# 2775  https://api.spotify.com/v1/tracks/0N4d44DDwQxB...
# 2776  https://api.spotify.com/v1/tracks/0LCMFLgIISg4...
# 2777  https://api.spotify.com/v1/tracks/2KpFQ5ETwtC3...
# ...                                                 ...
# 2889  https://api.spotify.com/v1/tracks/2uMQxOPITUiv...
# 2890  https://api.spotify.com/v1/tracks/2K0HJOlFioRN...
# 2891  https://api.spotify.com/v1/tracks/7iQY2alDQ2MV...
# 2892  https://api.spotify.com/v1/tracks/1PPswVdqYYvf...
# 2893  https://api.spotify.com/v1/tracks/6c5ghmeB5B3e...
#
#                                            analysis_url  time_signature
# 2773  https://api.spotify.com/v1/audio-analysis/49It...               3
# 2774  https://api.spotify.com/v1/audio-analysis/3imJ...               4
# 2775  https://api.spotify.com/v1/audio-analysis/0N4d...               3
# 2776  https://api.spotify.com/v1/audio-analysis/0LCM...               3
# 2777  https://api.spotify.com/v1/audio-analysis/2KpF...               3
# ...                                                 ...             ...
# 2889  https://api.spotify.com/v1/audio-analysis/2uMQ...               3
# 2890  https://api.spotify.com/v1/audio-analysis/2K0H...               4
# 2891  https://api.spotify.com/v1/audio-analysis/7iQY...               4
# 2892  https://api.spotify.com/v1/audio-analysis/1PPs...               3
# 2893  https://api.spotify.com/v1/audio-analysis/6c5g...               4
#
# [121 rows x 26 columns]
